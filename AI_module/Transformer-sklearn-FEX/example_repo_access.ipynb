# %% [markdown]
# ## Cloning an organization github repository using ssh

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# ADD HERE THE GIT CLONE LINK (the SSH one) to the repo you want to clone (it should start by git@github.com:...)
REPO_LINK = "git@github.com:ramonessix33/Hack-upc.git"

# %%
# run this command, when it asks you for the file path, input something inside your drive like "/content/drive/MyDrive/id_rsa"
# INFO: This only needs to be run once to create the key 
# !ssh-keygen -t rsa
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa): ^C

# %%
# copy the key to the /root/.ssh/ folder
import os
if not os.path.exists("/root/.ssh"):
  os.mkdir("/root/.ssh")
# !cp -R /content/drive/MyDrive/id_rsa* /root/.ssh/

# %%
# INFO: This only needs to be run once to connect the key in the github repository
# !cat /root/.ssh/id_rsa.pub

# %% [markdown]
# For the first time you are running this, copy the output of the previous cell and copy it to your github repo:
#  * Go to: https://github.com/settings/keys
#  * Click in "New ssh key"
#  * Copy the contents of the key to "Key" cell in the github page (add a title as well)
#  * Click "Add ssh key"

# %%
# add the key to know hosts
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-e301d840

# %%
# verify that the key is working
# !ssh -T git@github.com
# Out:
# Hi walzter! You've successfully authenticated, but GitHub does not provide shell access.

# %%
import os; os.chdir("/content/drive/MyDrive")

# %%
os.chdir("./Hack-upc")

# %%
# !git clone {REPO_LINK}
# Out:
# fatal: destination path 'Hack-upc' already exists and is not an empty directory.

# %%
# !git config --global user.email "ewalzthony@gmail.com"
# !git config --global user.name "walzter"

# %%
# !git add "AI_module/Transformer-sklearn-FEX/"

# %%
# !git commit -m "added Transformers, FEX & attempted to use multilabel sklearn"
# Out:
# [main a083151] added Transformers, FEX & attempted to use multilabel sklearn
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite AI_module/Transformer-sklearn-FEX/example_repo_access.ipynb (94%)

# %%
# !git push
# Out:
# ...
# ERROR: Permission to ramonessix33/Hack-upc.git denied to walzter.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
import tarfile
import os.path

def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

# %%
make_tarfile(output_filename = "data", source_dir = "./AI_module/Transformer-sklearn-FEX/data")
